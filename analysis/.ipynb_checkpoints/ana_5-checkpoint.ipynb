# %% [markdown]
# # Analysis 5
# ## Analyzing Map of Chicago with maximum Crime Occurrences in past 2 Years

# %%
#Import the required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %%
#Read the input file
df=pd.read_csv('../data/raw_data/Crimes_-_2001_to_present.csv')

# %%
#Print the input
df.head()
# Out:
#         ID Case Number                    Date                Block  IUCR  \
# 0  5708019    HN516812  08/07/2007 05:00:00 PM     018XX W 103RD ST  1310
# 1  5708022    HN515380  08/07/2007 09:00:00 PM    066XX S ELLIS AVE  1811
# 2  5708025    HN516837  08/03/2007 10:00:00 AM  054XX W WINDSOR AVE  1310
# 3  5708028    HN516787  08/03/2007 04:30:00 PM     001XX N STATE ST  0820
# 4  5708029    HN495945  07/29/2007 10:02:00 AM  078XX S BENNETT AVE  2017
#
#       Primary Type                   Description      Location Description  \
# 0  CRIMINAL DAMAGE                   TO PROPERTY         CONSTRUCTION SITE
# 1        NARCOTICS  POSS: CANNABIS 30GMS OR LESS  SCHOOL, PUBLIC, BUILDING
# 2  CRIMINAL DAMAGE                   TO PROPERTY                 RESIDENCE
# 3            THEFT                $500 AND UNDER        GROCERY FOOD STORE
# 4        NARCOTICS            MANU/DELIVER:CRACK    VEHICLE NON-COMMERCIAL
#
# ...

# %%
#Limiting data for past 2 years
df = df[df['Year'] > 2014]

# %%
#Lets try to plot Crime on map based on Geolocation
east = df['Longitude'].max()
west = df['Longitude'].min()
north = df['Latitude'].max()
south = df['Latitude'].min()
#lon = df['Longitude'].mean()
#lat = df['Latitude'].mean()

fig,ax = plt.subplots(figsize = (10,10))
ax.set_title("Chicago Crime Heat Map in Last 2 Years")

m = Basemap(projection='merc', llcrnrlat=south, urcrnrlat=north,
            llcrnrlon=west, urcrnrlon=east, lat_ts=south, resolution='h')

m.drawmapboundary(fill_color='#46bcec')
#m.fillcontinents(lake_color='aqua')
m.drawcoastlines()

x, y = m(df['Longitude'].values, df['Latitude'].values)
m.hexbin(x, y, gridsize=250, bins='log', cmap='inferno');
if not os.path.exists('ana_5'):
    os.makedirs('ana_5')
plt.savefig('ana_5/Chicago Crime Heat Map in Last 2 Years')
# Out:
# C:\Users\swaru\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3534: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# C:\Users\swaru\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3541: RuntimeWarning: invalid value encountered in greater
#   x = ma.masked_values(np.where(x > 1.e20,1.e20,x), 1.e20)
# C:\Users\swaru\Anaconda3\lib\site-packages\numpy\ma\core.py:2296: RuntimeWarning: invalid value encountered in less_equal
#   mabs(xnew - value), atol + rtol * mabs(value))
# C:\Users\swaru\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3547: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# ### Inference
# - The Bright spots show more crime activity in past 2 years and light spots show less crime activity in past 2 years.
# - Brighter the spot more is it unsafe to stay in that locality.
# - If someone is considering moving to Chicago, they should try to live near places with light spots so as to avoid Crime activity.
